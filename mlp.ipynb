# %% [markdown]
# # **Setup**

# %%
# @title Update LIbraries
# !pip install --upgrade kagglehub
# !pip install kagglehub[pandas-datasets]
# !pip install kagglehub[hf-datasets]

# %%
# @title Import Library

# data manipulation
import numpy as np
import pandas as pd

# dataset
import kagglehub
from kagglehub import KaggleDatasetAdapter

# preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

from sklearn.utils.class_weight import compute_class_weight

# mlp
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping

# model evaluation
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn.metrics import precision_recall_curve

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# @title Import Dataset
raw_dataset = kagglehub.load_dataset(
    KaggleDatasetAdapter.PANDAS,
    "mlg-ulb/creditcardfraud",
    "creditcard.csv",
)

# %% [markdown]
# # Data Exploration

# %%
raw_dataset
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
# @title Info
types = raw_dataset.dtypes
nulls = raw_dataset.isnull().sum()

info = pd.DataFrame({"types": types, "nulls": nulls})
info
# Out:
#           types  nulls
# Time    float64      0
# V1      float64      0
# V2      float64      0
# V3      float64      0
# V4      float64      0
# V5      float64      0
# V6      float64      0
# V7      float64      0
# V8      float64      0
# V9      float64      0
# V10     float64      0
# V11     float64      0
# V12     float64      0
# V13     float64      0
# V14     float64      0
# V15     float64      0
# V16     float64      0
# V17     float64      0
# V18     float64      0
# V19     float64      0
# V20     float64      0
# V21     float64      0
# V22     float64      0
# V23     float64      0
# V24     float64      0
# V25     float64      0
# V26     float64      0
# V27     float64      0
# V28     float64      0
# Amount  float64      0
# Class     int64      0

# %%
# @title Describe
raw_dataset.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
# @title Class Distribution
class_count = raw_dataset["Class"].value_counts()
class_count
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# # **Dataset Preprocessing**

# %%
dataset = raw_dataset.copy()

# %%
# @title Scale Time and Amount
scaler = StandardScaler()
dataset["Time"] = scaler.fit_transform(dataset[["Time"]])
dataset["Amount"] = scaler.fit_transform(dataset[["Amount"]])

# %%
# @title Split Dataset
X = dataset.drop("Class", axis=1)
y = dataset["Class"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12, stratify=y)

# %%
smote = SMOTE(sampling_strategy=0.5, random_state=42)
X_train, y_train = smote.fit_resample(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py:354: FutureWarning: The SMOTE or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(

# %%
# @title Distribution# Original dataset distribution
print("Original dataset class distribution:")
print(y.value_counts(normalize=True))

# Training set distribution
print("\nTraining set class distribution:")
print(y_train.value_counts(normalize=True))

# Testing set distribution
print("\nTesting set class distribution:")
print(y_test.value_counts(normalize=True))
# Out:
# Original dataset class distribution:
# Class
# 0    0.998273
# 1    0.001727
# Name: proportion, dtype: float64
#
# Training set class distribution:
# Class
# 0    0.666668
# 1    0.333332
# Name: proportion, dtype: float64
#
# Testing set class distribution:
# Class
# 0    0.99828
# 1    0.00172
# Name: proportion, dtype: float64

# %% [markdown]
# # **Train Model**

# %%
model = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(128, activation="relu"),
    Dropout(0.2),
    Dense(32, activation="relu"),
    Dropout(0.2),
    Dense(8, activation="relu"),
    Dropout(0.2),
    Dense(1, activation="sigmoid")
])

# %%
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(zip(np.unique(y_train), class_weights))

# %%
model.compile(
    Adam(learning_rate=0.001),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
# early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %%
history = model.fit(X_train, y_train, epochs=20, batch_size=32, class_weight=class_weight_dict, validation_split=0.2)
# Out:
# Epoch 1/20
# 8530/8530 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9712 - loss: 0.0865 - val_accuracy: 0.9993 - val_loss: 0.0071
# Epoch 2/20
# 8530/8530 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - accuracy: 0.9957 - loss: 0.0168 - val_accuracy: 0.9992 - val_loss: 0.0045
# Epoch 3/20
# 8530/8530 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - accuracy: 0.9975 - loss: 0.0108 - val_accuracy: 0.9991 - val_loss: 0.0119
# Epoch 4/20
# 8530/8530 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - accuracy: 0.9981 - loss: 0.0092 - val_accuracy: 0.9992 - val_loss: 0.0025
# Epoch 5/20
# 8530/8530 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.9983 - loss: 0.0084 - val_accuracy: 0.9998 - val_loss: 0.0013
# Epoch 6/20
# 8530/8530 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - accuracy: 0.9987 - loss: 0.0074 - val_accuracy: 0.9995 - val_loss: 0.0032
# Epoch 7/20
# 8530/8530 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - accuracy: 0.9986 - loss: 0.0071 - val_accuracy: 0.9988 - val_loss: 0.0038
# Epoch 8/20
# ...

# %% [markdown]
# # **Evaluate Model**

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9991 - loss: 0.0081
# Test Loss: 0.00889509730041027, Test Accuracy: 0.9990870952606201

# %%
# Generate predictions
y_pred = (model.predict(X_test) > 0.5).astype("int32")

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Class 0", "Class 1"])
disp.plot(cmap="Blues")

# Display the plot
plt.title("Confusion Matrix")
plt.show()

# Optionally, print the classification report
print(classification_report(y_test, y_pred))
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.68      0.88      0.77        98
#
#     accuracy                           1.00     56962
#    macro avg       0.84      0.94      0.88     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
precision, recall, thresholds = precision_recall_curve(y_test, y_pred)
plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()

# %% [markdown]
# Summary of Approaches:
#
# Resampling: Use SMOTE, random over-sampling, or under-sampling to balance the classes.
#
# Class Weights: Increase the weight of the minority class to give it more importance.
#
# Ensemble Methods: Use methods like Random Forests, XGBoost, or ensemble models to capture patterns better.
#
# Appropriate Metrics: Focus on precision, recall, F1-score, or ROC-AUC instead of accuracy.
#
# Cost-sensitive Learning: Modify the loss function to penalize errors on the minority class.
#
# Anomaly Detection: Consider framing the problem as anomaly detection when the class imbalance is very severe.
